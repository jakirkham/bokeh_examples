# %%
from scipy.misc import ascent
import bokeh.plotting as bp
from bokeh.resources import CDN
from bokeh.embed import file_html

import numpy

from IPython.display import display, HTML

# %%
img = ascent()/256.0

plot = bp.figure(plot_width=img.shape[0], plot_height=img.shape[1], 
                 x_range=[0, img.shape[0]], y_range=[0, img.shape[1]])
plot.image(image=[numpy.flipud(img)], x=[0], y=[0],
           dw=[img.shape[0]], dh=[img.shape[1]])

html = file_html(plot, CDN, "my plot")

display(HTML(html))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>my plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.3.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.3.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="plotdiv" id="9229db7b-0940-4483-b85b-82a344f00dd3"></div>
#         </div>
#
#         <script type="text/javascript">
#             Bokeh.$(function() {
#             Bokeh.safely(function() {
#                 var docs_json = {"bf61c8c2-5ddb-4a44-b1d3-93b021493d48":{"roots":{"references":[{"attributes":{"callback":null,"end":512},"id":"cb1ec68a-8319-40e4-a45e-dd6e6ee0d2fa","type":"Range1d"},{"attributes":{"plot":{"id":"7f342542-880e-4393-8ef2-2e1fa2252218","subtype":"Figure","type":"Plot"},"ticker":{"id":"6214935b-18ed-433c-a865-1980af128152","type":"BasicTicker"}},"id":"7df7586f-4f55-4b9c-a3ca-29421f40c0de","type":"Grid"},{"attributes":{},"id":"d0d2eed3-3133-46a1-b69b-27fd0b088d68","type":"ToolEvents"},{"attributes":{},"id":"70925a14-9f41-4181-bb3f-36ae852635ed","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2a3e4392-f3d4-45a1-a3e7-f74216771641","type":"PanTool"},{"id":"2ee42edf-a166-4392-bd3a-83f100affbe7","type":"WheelZoomTool"},{"id":"df1033de-6c46-42a2-9f17-8172ce351346","type":"BoxZoomTool"},{"id":"bf497de1-2da6-4578-badd-252f56158518","type":"SaveTool"},{"id":"fd33d9f8-10ec-4fa3-9550-a22b8e6f5437","type":"ResetTool"},{"id":"c2aa0cc5-7daa-4de1-b2d9-96a0c3fe353c","type":"HelpTool"}]},"id":"585f32ea-8067-4626-8d87-cd13fb3b3a04","type":"Toolbar"},{"attributes":{"data_source":{"id":"5e991b24-0b34-48cb-bd0e-655f1ecc26e3","type":"ColumnDataSource"},"glyph":{"id":"243f40cd-6f2c-41ce-86d3-1867507f9b62","type":"Image"},"hover_glyph":null,"nonselection_glyph":{"id":"92515278-c5b9-41c4-a7fd-e3bd65cb40c2","type":"Image"},"selection_glyph":null},"id":"41f1d691-43d0-494b-8924-7c2a60791821","type":"GlyphRenderer"},{"attributes":{"palette":["#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff"]},"id":"447196cb-fcc4-486a-a8e1-6b5d28750295","type":"LinearColorMapper"},{"attributes":{},"id":"6214935b-18ed-433c-a865-1980af128152","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"7f342542-880e-4393-8ef2-2e1fa2252218","subtype":"Figure","type":"Plot"},"ticker":{"id":"85891f0f-3f93-4afc-b89c-f89b6b75e7be","type":"BasicTicker"}},"id":"ce27956c-82cc-4c7b-a636-deff7be75769","type":"Grid"},{"attributes":{"color_mapper":{"id":"447196cb-fcc4-486a-a8e1-6b5d28750295","type":"LinearColorMapper"},"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"243f40cd-6f2c-41ce-86d3-1867507f9b62","type":"Image"},{"attributes":{"plot":null,"text":null},"id":"a91113bb-e2bb-4cd2-aae0-b47b5cc30e2a","type":"Title"},{"attributes":{"plot":{"id":"7f342542-880e-4393-8ef2-2e1fa2252218","subtype":"Figure","type":"Plot"}},"id":"bf497de1-2da6-4578-badd-252f56158518","type":"SaveTool"},{"attributes":{"below":[{"id":"4a0d90df-d0ae-42f4-bb79-afaa27e95cc4","type":"LinearAxis"}],"left":[{"id":"54c54083-defe-49b3-b9b8-1772f58dde71","type":"LinearAxis"}],"plot_height":512,"plot_width":512,"renderers":[{"id":"4a0d90df-d0ae-42f4-bb79-afaa27e95cc4","type":"LinearAxis"},{"id":"7df7586f-4f55-4b9c-a3ca-29421f40c0de","type":"Grid"},{"id":"54c54083-defe-49b3-b9b8-1772f58dde71","type":"LinearAxis"},{"id":"ce27956c-82cc-4c7b-a636-deff7be75769","type":"Grid"},{"id":"9da67c42-cac8-4582-88df-8149cc3d5c2d","type":"BoxAnnotation"},{"id":"41f1d691-43d0-494b-8924-7c2a60791821","type":"GlyphRenderer"}],"title":{"id":"a91113bb-e2bb-4cd2-aae0-b47b5cc30e2a","type":"Title"},"tool_events":{"id":"d0d2eed3-3133-46a1-b69b-27fd0b088d68","type":"ToolEvents"},"toolbar":{"id":"585f32ea-8067-4626-8d87-cd13fb3b3a04","type":"Toolbar"},"x_range":{"id":"cb1ec68a-8319-40e4-a45e-dd6e6ee0d2fa","type":"Range1d"},"y_range":{"id":"660b911f-e12a-4740-8308-746b2e05d023","type":"Range1d"}},"id":"7f342542-880e-4393-8ef2-2e1fa2252218","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"end":512},"id":"660b911f-e12a-4740-8308-746b2e05d023","type":"Range1d"},{"attributes":{},"id":"bdc9cd7d-db54-48c5-81c0-f986b24f33f8","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"70925a14-9f41-4181-bb3f-36ae852635ed","type":"BasicTickFormatter"},"plot":{"id":"7f342542-880e-4393-8ef2-2e1fa2252218", ...
