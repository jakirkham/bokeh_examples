# %%
import colorsys

import numpy as np

from bokeh import plotting as bkplt
from bokeh.models import LinearColorMapper, HoverTool, TapTool
from bokeh.models import CustomJS
from bokeh.models.widgets import Slider
from bokeh.layouts import column, row
from bokeh.resources import CDN
from bokeh.embed import file_html

from IPython.display import display, HTML

bkplt.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="b57c1169-7124-48e4-8dcd-99a0ec30ed53">Loading BokehJS ...</span>
#     </div>

# %%
# initialise a white block for the first plot
x = [0]
y = [0]
alpha = 1.0

# create a data source to enable refreshing of fill & text color
source = bkplt.ColumnDataSource(data=dict(x = x, y = y, alpha = [alpha]))

tools1 = 'reset, save'

# create first plot, as a rect() glyph and centered text label, with fill and text color taken from source
p1 = bkplt.figure(x_range=(-8, 8), y_range=(-4, 4), plot_width=600, plot_height=300, title=None, tools=tools1)
color_block = p1.rect(x='x', y='y', width=18, height=10, fill_color='#000000', alpha='alpha', line_color = '#000000', source=source)

# the callback function to update the color of the block and associated label text
callback = CustomJS(args=dict(source=source), code="""
    var data = source.get('data');
    var AS = alpha_slider;
    alpha = data['alpha'];
    var alpha_from_slider = AS.get('value');
    alpha[0] = alpha_from_slider;
    source.trigger('change');
""")

# create slider tool objects to control the RGB levels for first plot. Set callback function to allow refresh
alpha_slider = Slider(start=0.0, end=1.0, value=1.0, step=0.01, title="A", callback=callback)
callback.args['alpha_slider'] = alpha_slider

# get rid of axis details for cleaner look
p1.ygrid.grid_line_color = None
p1.xgrid.grid_line_color = None
p1.axis.axis_line_color  = None
p1.axis.major_label_text_color = None
p1.axis.major_tick_line_color = None
p1.axis.minor_tick_line_color = None

layout = row(
    column(alpha_slider),
    column(p1)
)


html = file_html(layout, CDN, "my plot")
display(HTML(html))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>my plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.3.min.css" type="text/css" />
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.3.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.3.min.js"></script>
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.3.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="plotdiv" id="0e5cf5aa-8220-4a3d-b2fd-201772e964e0"></div>
#         </div>
#
#         <script type="text/javascript">
#             Bokeh.$(function() {
#             Bokeh.safely(function() {
#                 var docs_json = {"a1ebc1de-7112-491c-92e1-cbc44ef85a1f":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"c6d5857b-bb1c-412b-854a-58baffc5f0b1","type":"Title"},{"attributes":{"plot":{"id":"2d477288-4d98-4d29-a243-7a1b09a5bf16","subtype":"Figure","type":"Plot"}},"id":"12096936-9193-4071-94ac-9a19ff0fb8b6","type":"SaveTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":10},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":18},"x":{"field":"x"},"y":{"field":"y"}},"id":"8155f0c2-7358-4c43-b43c-ada4dae31197","type":"Rect"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"2d477288-4d98-4d29-a243-7a1b09a5bf16","subtype":"Figure","type":"Plot"},"ticker":{"id":"f7a69561-b102-4aab-ae72-b1585a6b3418","type":"BasicTicker"}},"id":"58700ccd-78a6-40a0-a445-01fa0a531895","type":"Grid"},{"attributes":{"below":[{"id":"ebdfbe0c-6fda-46f6-bb4b-0d1da63a1258","type":"LinearAxis"}],"left":[{"id":"283fc8b4-1310-47e9-b439-9ae921ce018b","type":"LinearAxis"}],"plot_height":300,"renderers":[{"id":"ebdfbe0c-6fda-46f6-bb4b-0d1da63a1258","type":"LinearAxis"},{"id":"11b9d7db-f81e-4ce2-81b2-5ec2b3affe0a","type":"Grid"},{"id":"283fc8b4-1310-47e9-b439-9ae921ce018b","type":"LinearAxis"},{"id":"58700ccd-78a6-40a0-a445-01fa0a531895","type":"Grid"},{"id":"0c57206b-1ddb-4050-8921-06c83621e5d8","type":"GlyphRenderer"}],"title":{"id":"c6d5857b-bb1c-412b-854a-58baffc5f0b1","type":"Title"},"tool_events":{"id":"ea90f45e-ba9b-4614-afd2-d39ef0998c04","type":"ToolEvents"},"toolbar":{"id":"fac1bec5-022a-4652-b57b-8e72ad920915","type":"Toolbar"},"x_range":{"id":"7147528d-e7f8-4d40-a579-a3f6b651532b","type":"Range1d"},"y_range":{"id":"bb17bc9c-4622-4f17-9306-9ccc82687326","type":"Range1d"}},"id":"2d477288-4d98-4d29-a243-7a1b09a5bf16","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"field":"alpha"},"fill_color":{"value":"#000000"},"height":{"units":"data","value":10},"line_alpha":{"field":"alpha"},"line_color":{"value":"#000000"},"width":{"units":"data","value":18},"x":{"field":"x"},"y":{"field":"y"}},"id":"96d55035-9e73-4001-b821-d218c77674a2","type":"Rect"},{"attributes":{"args":{"alpha_slider":{"id":"6e6417e9-e281-4204-9acd-96e7cff3ff36","type":"Slider"},"source":{"id":"7f373ba2-c4c4-4683-8364-fddf18d191f6","type":"ColumnDataSource"}},"code":"\n    var data = source.get('data');\n    var AS = alpha_slider;\n    alpha = data['alpha'];\n    var alpha_from_slider = AS.get('value');\n    alpha[0] = alpha_from_slider;\n    source.trigger('change');\n"},"id":"614246b5-9e39-4f6b-90d9-2b19414d88ce","type":"CustomJS"},{"attributes":{"children":[{"id":"6e6417e9-e281-4204-9acd-96e7cff3ff36","type":"Slider"}]},"id":"ecfb5167-b77c-44d6-a5e2-d98cb5f4b654","type":"WidgetBox"},{"attributes":{"callback":{"id":"614246b5-9e39-4f6b-90d9-2b19414d88ce","type":"CustomJS"},"step":0.01,"title":"A","value":1.0},"id":"6e6417e9-e281-4204-9acd-96e7cff3ff36","type":"Slider"},{"attributes":{"data_source":{"id":"7f373ba2-c4c4-4683-8364-fddf18d191f6","type":"ColumnDataSource"},"glyph":{"id":"96d55035-9e73-4001-b821-d218c77674a2","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"8155f0c2-7358-4c43-b43c-ada4dae31197","type":"Rect"},"selection_glyph":null},"id":"0c57206b-1ddb-4050-8921-06c83621e5d8","type":"GlyphRenderer"},{"attributes":{},"id":"46a5d242-f758-474d-87f6-16796b25aa81","type":"BasicTickFormatter"},{"attributes":{"children":[{"id":"2d477288-4d98-4d29-a243-7a1b09a5bf16","subtype":"Figure","type":"Plot"}]},"id":"58985414-01dd-45c3-8e75-25f7b1a01a35","type":"Column"},{"attributes":{},"id":"0b51272a-6197-4692-9dab-fae40c576f92","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":8,"start":-8},"id":"7147528d-e7f8-4d40-a579-a3f6b651532b","type":"Range1d"},{"attributes":{"children":[{"id":"ec13b509-bef3-4c2c-b77c-fcd944f6f182","type":"Column"},{"id":"58985414-01dd-45c3-8e75-25f7b1a01a35","type":"Col ...
#                 var render_items = [{"docid":"a1ebc1de-7112-491c-92e1-cbc44ef85a1f","elementid":"0e5cf5aa-8220-4a3d-b2fd-201772e964e0","modelid":"63554abd-185d-428d-a80b-181bf70ee18b"}];
#
#                 Bokeh.embed.embed_items(docs_json, render_items);
#             });
#         });
#         </script>
#     </body>
