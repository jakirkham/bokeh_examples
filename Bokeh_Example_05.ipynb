# %%
from bokeh import io as bi
from bokeh import plotting as bp
from bokeh.layouts import column, row
from bokeh.models import CustomJS
from bokeh.models.widgets import Slider
from bokeh.resources import CDN
from bokeh.embed import file_html

from IPython.display import display, HTML

import numpy as np


bp.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5a2b6e24-7f84-47b9-894b-9160f9d6e2c4">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0, 10, 500)
y = np.sin(x)

source = bp.ColumnDataSource(data=dict(x=x, y=y))


plot = bp.figure(y_range=(-10, 10), plot_width=400, plot_height=400)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

callback = CustomJS(args=dict(source=source), code="""
    var data = source.get('data');
    var A = amp.get('value')
    var k = freq.get('value')
    var phi = phase.get('value')
    var B = offset.get('value')
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = B + A*Math.sin(k*x[i]+phi);
    }
    source.trigger('change');
""")

amp_slider = Slider(start=0.1, end=10, value=1, step=.1, title="Amplitude", callback=callback)
callback.args["amp"] = amp_slider

freq_slider = Slider(start=0.1, end=10, value=1, step=.1, title="Frequency", callback=callback)
callback.args["freq"] = freq_slider

phase_slider = Slider(start=0, end=6.4, value=0, step=.1, title="Phase", callback=callback)
callback.args["phase"] = phase_slider

offset_slider = Slider(start=-5, end=5, value=0, step=.1, title="Offset", callback=callback)
callback.args["offset"] = offset_slider

layout = row(
    plot,
    column(amp_slider, freq_slider, phase_slider, offset_slider),
)

html = file_html(layout, CDN, "my plot")

display(HTML(html))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="utf-8">
#         <title>my plot</title>
#
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-0.12.3.min.css" type="text/css" />
# <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.3.min.css" type="text/css" />
#
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-0.12.3.min.js"></script>
# <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.12.3.min.js"></script>
# <script type="text/javascript">
#     Bokeh.set_log_level("info");
# </script>
#         <style>
#           html {
#             width: 100%;
#             height: 100%;
#           }
#           body {
#             width: 90%;
#             height: 100%;
#             margin: auto;
#           }
#         </style>
#     </head>
#     <body>
#
#         <div class="bk-root">
#             <div class="plotdiv" id="45336de8-00df-425f-994b-8e37aac47270"></div>
#         </div>
#
#         <script type="text/javascript">
#             Bokeh.$(function() {
#             Bokeh.safely(function() {
#                 var docs_json = {"480d20a7-2d6c-4d6d-a3ff-5c8a53327191":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"6e370ca6-9bc9-4f88-8cb9-e032c13928ee","subtype":"Figure","type":"Plot"},"ticker":{"id":"93e505be-72aa-4088-8672-8ac2a1128e75","type":"BasicTicker"}},"id":"b825c4bb-869b-4c7a-ad2f-5f94f5815217","type":"Grid"},{"attributes":{"children":[{"id":"6e370ca6-9bc9-4f88-8cb9-e032c13928ee","subtype":"Figure","type":"Plot"},{"id":"273f303e-008a-4fc6-9971-8c6eb6523dc1","type":"Column"}]},"id":"c4947b9a-59d9-4ca9-80e8-6af2db029931","type":"Row"},{"attributes":{},"id":"2794d950-3e96-4716-9769-35354f7b6a2d","