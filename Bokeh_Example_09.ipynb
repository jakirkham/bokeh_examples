# %%
from random import random

import bokeh
from bokeh.models import CustomJS, ColumnDataSource
from bokeh.layouts import column, row
from bokeh.plotting import figure, output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9e823dd1-48ca-46a4-8838-6ac7958ecf78">Loading BokehJS ...</span>
#     </div>

# %%
x = [random() for x in range(500)]
y = [random() for y in range(500)]

s1 = ColumnDataSource(data=dict(x=x, y=y))
p1 = figure(plot_width=400, plot_height=400, tools="lasso_select", title="Select Here")
p1.circle('x', 'y', source=s1, alpha=0.6)

s2 = ColumnDataSource(data=dict(x=[], y=[]))
p2 = figure(plot_width=400, plot_height=400, x_range=(0,1), y_range=(0,1),
            tools="", title="Watch Here")
p2.circle('x', 'y', source=s2, alpha=0.6)

s1.callback = CustomJS(args=dict(s2=s2), code="""
    var inds = cb_obj.get('selected')['1d'].indices;
    var d1 = cb_obj.get('data');
    var d2 = s2.get('data');
    d2['x'] = []
    d2['y'] = []
    for (i = 0; i < inds.length; i++) {
        d2['x'].push(d1['x'][inds[i]])
        d2['y'].push(d1['y'][inds[i]])
    }
    s2.trigger('change');
""")

layout = row(p1, p2)

show(layout)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="3f17cb5d-59c7-456c-8034-ac7ceb961db1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#3f17cb5d-59c7-456c-8034-ac7ceb961db1").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3f17cb5d-59c7-456c-8034-ac7ceb961db1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3f17cb5d-59c7-456c-8034-ac7ceb961db1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0f0abb3b-4f05-4326-bc89-c45727cf72de":{"roots":{"references":[{"attributes":{"data_source":{"id":"02b82ddb-78ab-40dd-9565-fa95a2ab8e4c","type":"ColumnDataSource"},"glyph":{"id":"33f27a59-909e-46e1-bb68-06584e49ad92","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"6c34d831-f062-4d80-88ee-78337c924f97","type":"Circle"},"selection_glyph":null},"id":"60ea43d4-2db6-4958-a215-5d5fdadddd3e","type":"GlyphRenderer"},{"attributes":{"args":{"s2":{"id":"721e6a86-5305-4e38-94a0-4d9c486a07de","type":"ColumnDataSource"}},"code":"\n    var inds = cb_obj.get('selected')['1d'].indices;\n    var d1 = cb_obj.get('data');\n    var d2 = s2.get('data');\n    d2['x'] = []\n    d2['y'] = []\n    for (i = 0; i < inds.length; i++) {\n        d2['x'].push(d1['x'][inds[i]])\n        d2['y'].push(d1['y'][inds[i]])\n    }\n    s2.trigger('change');\n"},"id":"5c895b4e-d96f-445e-a209-7b9d7e09ff29","type":"CustomJS"},{"attributes":{"callback":null,"overlay":{"id":"9f0dbedd-9d4f-4c28-b827-d4ff3b7a5de3","type":"PolyAnnotation"},"plot":{"id":"c8ccf67e-4442-49a6-ac78-385e9a2bed04","subtype":"Figure","type":"Plot"}},"id":"dbb56175-aa70-4310-9b8e-92a3351c121e","type":"LassoSelectTool"},{"attributes":{},"id":"99f770fd-c5e3-43a8-8183-882ba83a2c15","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c8ccf67e-4442-49a6-ac78-385e9a2bed04","subtype":"Figure","type":"Plot"},"ticker":{"id":"392bf331-fc0c-4e05-bf58-56fdbfd99417","type":"BasicTicker"}},"id":"4f4eb0d6-03c6-4a67-96b1-86791bfccffa","type":"Grid"},{"attributes":{"callback":null},"id":"a40daee4-d8e1-4287-a9ea-44b8c7828e37","type":"Range1d"},{"attributes":{"callback":null},"id":"75f89a71-45b7-4301-bba8-2270835dc255","type":"DataRange1d"},{"attributes":{"data_source":{"id":"721e6a86-5305-4e38-94a0-4d9c486a07de","type":"ColumnDataSource"},"glyph":{"id":"cf3b7bee-92c9-407c-b871-f534cb235a98","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"202070a8-13e3-4bf3-866a-1642d1c912b8","type":"Circle"},"selection_glyph":null},"id":"6c90edd1-67a7-48f6-82c8-2d99e3b4db31","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.6},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cf3b7bee-92c9-407c-b871-f534cb235a98","type":"Circle"},{"attributes":{"plot":null,"text":"Watch Here"},"id":"5c3cb591-25ce-46ff-bfdc-9abe7a35e756","type":"Title"},{"attributes":{"plot":{"id":"83dcace7-cc56-4b46-9c1f-8fe94b5868ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"67cc3503-2d19-4d7b-9b95-e11261c1f3ba","type":"BasicTicker"}},"id":"38b69e80-4aca-4d74-80b7-e3fba3bad879","type":"Grid"},{"attributes":{},"id":"3ce3491e-4585-4efa-b732-fd6ef496737a","type":"ToolEvents"},{"attributes":{"formatter":{"id":"ead3e385-c0ed-4444-9574-7a68dc66113d","type":"BasicTickFormatter"},"plot":{"id":"83dcace7-cc56-4b46-9c1f-8fe94b5868ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"149b3477-77d6-475f-a5df-40a28286f400","type":"BasicTicker"}},"id":"970fb8e4-a61c-4135-b19d-c6960b3113ba","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"c8ccf67e-4442-49a6-ac78-385e9a2bed04","subtype":"Figure","type":"Plot"},"ticker":{"id":"76808161-a020-4dab-9abd-6592792d75da","type":"BasicTicker"}},"id":"ea38978b-b001-472e-84c9-aebc912e743e","type":"Grid"},{"attributes":{"formatter":{"id":"99f770fd-c5e3-43a8-8183-882ba83a2c15","type":"BasicTickFormatter"},"plot":{"id":"83dcace7-cc56-4b46-9c1f-8fe94b5868ff","subtype":"Figure","type":"Plot"},"ticker":{"id":"67cc3503-2d19-4d7b-9b95-e11261c1f3ba","type":"BasicTicker"}},"id":"daa26b4a-e8a3-417f-a511-e3f87837df7a","type":"LinearAxis"},{"attributes":{},"id":"76808161-a020-4dab-9abd-6592792d75da","type":"BasicTicker"},{"attributes":{},"id":"392bf331-fc0c-4e05-bf58-56fdbfd99417","type":"BasicTicker"},{"attributes":{},"id":"67cc3503-2d19-4d7b-9b95-e11261c1f3ba","type":"BasicTicker"},{"attributes":{"formatter":{"id":"f725235f-f0ad-4b35-897c-86b2a54e8580","type":"BasicTi ...

# %%
bokeh.__version__
# Out:
# '0.12.3'
